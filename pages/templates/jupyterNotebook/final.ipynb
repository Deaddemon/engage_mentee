# %%
import numpy as np  
import pandas as pd
import seaborn as sns
import mpld3
import pandas_profiling as pp
import matplotlib.pyplot as plt
# %matplotlib inline
import squarify

# %%
#data loading
df = pd.read_csv("dataset/data.csv")

# %%
#data cleaning
df_data = df.replace('?',np.NAN) 
df_data.isnull().sum()
# Out:
# fuel-type           0
# body-style          0
# drive-wheels        0
# wheel-base          0
# curb-weight         0
# num-of-cylinders    0
# engine-size         0
# horsepower          2
# peak-rpm            2
# city-mpg            0
# highway-mpg         0
# price               4
# dtype: int64

# %%
df_temp = df[df['price']!='?']
normalised_mean = df_temp['price'].astype(int).mean()
df['price'] = df['price'].replace('?',normalised_mean).astype(int)

df_temp = df[df['horsepower']!='?']
normalised_mean = df_temp['horsepower'].astype(int).mean()
df['horsepower'] = df['horsepower'].replace('?',normalised_mean).astype(int)

df_temp = df[df['peak-rpm']!='?']
normalised_mean = df_temp['peak-rpm'].astype(int).mean()
df['peak-rpm'] = df['peak-rpm'].replace('?',normalised_mean).astype(int)



df['num-of-cylinders']= df['num-of-cylinders'].replace('two', 2)
df['num-of-cylinders']= df['num-of-cylinders'].replace('three', 3)
df['num-of-cylinders']= df['num-of-cylinders'].replace('four', 4)
df['num-of-cylinders']= df['num-of-cylinders'].replace('five', 5)
df['num-of-cylinders']= df['num-of-cylinders'].replace('six', 6)
df['num-of-cylinders']= df['num-of-cylinders'].replace('eight', 8)
df['num-of-cylinders']= df['num-of-cylinders'].replace('twelve', 12)

# %%
df.describe()
# Out:
#        wheel-base  curb-weight  num-of-cylinders  engine-size  horsepower  \
# count  205.000000   205.000000        205.000000   205.000000  205.000000
# mean    98.756585  2555.565854          4.380488   126.907317  104.253659
# std      6.021776   520.680204          1.080854    41.642693   39.519219
# min     86.600000  1488.000000          2.000000    61.000000   48.000000
# 25%     94.500000  2145.000000          4.000000    97.000000   70.000000
# 50%     97.000000  2414.000000          4.000000   120.000000   95.000000
# 75%    102.400000  2935.000000          4.000000   141.000000  116.000000
# max    120.900000  4066.000000         12.000000   326.000000  288.000000
#
#           peak-rpm    city-mpg  highway-mpg         price
# count   205.000000  205.000000   205.000000    205.000000
# mean   5125.365854   25.219512    30.751220  13207.126829
# std     476.979095    6.542142     6.886443   7868.768212
# min    4150.000000   13.000000    16.000000   5118.000000
# ...

# %%
from pandas_profiling import ProfileReport
 
profile = ProfileReport(df)
profile.to_file(output_file="report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # general findings

# %%
df[['engine-size','peak-rpm','curb-weight','horsepower','price', 'wheel-base', 'city-mpg', 'highway-mpg',]].hist(figsize=(10,6),bins=6,color='pink')
plt.tight_layout()
plt.show()

#Distribution of data on an interval scale

# %%
engineSize, ax = plt.subplots()
ax= df['engine-size'].hist(figsize=(9,5),bins=6,color='pink') 
 
plt.title("engine-size")

html_str = mpld3.fig_to_html(engineSize)
html_file= open("files/engine_size_histogram.html","w")
html_file.write(html_str)
html_file.close()

# %%
peakRpm, ax = plt.subplots()
ax= df['peak-rpm'].hist(figsize=(9,5),bins=6,color='pink') 
 
plt.title("peak-rpm")

html_str = mpld3.fig_to_html(peakRpm)
html_file= open("files/peak_rpm_histogram.html","w")
html_file.write(html_str)
html_file.close()

# %%
curbWeight, ax = plt.subplots()
ax= df['curb-weight'].hist(figsize=(9,5),bins=6,color='pink') 
 
plt.title("curb-weight" )

html_str = mpld3.fig_to_html(curbWeight)
html_file= open("files/curb_weight_histogram.html","w")
html_file.write(html_str)
html_file.close()

# %%
horsepower, ax = plt.subplots()
ax= df['horsepower'].hist(figsize=(9,5),bins=6,color='pink') 
 
plt.title("horsepower" )

html_str = mpld3.fig_to_html(horsepower)
html_file= open("files/horsepower_histogram.html","w")
html_file.write(html_str)
html_file.close()

# %%
price, ax = plt.subplots()
ax= df['price'].hist(figsize=(9,5),bins=6,color='pink') 
 
plt.title("price" )

html_str = mpld3.fig_to_html(price)
html_file= open("files/price_histogram.html","w")
html_file.write(html_str)
html_file.close()

# %%
wheelBase, ax = plt.subplots()
ax= df['wheel-base'].hist(figsize=(9,5),bins=6,color='pink') 
 
plt.title("wheel-base" )

html_str = mpld3.fig_to_html(wheelBase)
html_file= open("files/wheel_base_histogram.html","w")
html_file.write(html_str)
html_file.close()

# %%
cityMpg, ax = plt.subplots()
ax= df['city-mpg'].hist(figsize=(9,5),bins=6,color='pink') 
 
plt.title("city-mpg" )

html_str = mpld3.fig_to_html(cityMpg)
html_file= open("files/city_mpg_histogram.html","w")
html_file.write(html_str)
html_file.close()

# %%
highwayMpg, ax = plt.subplots()
ax= df['highway-mpg'].hist(figsize=(9,5),bins=6,color='pink') 
 
plt.title("highway-mpg" )

html_str = mpld3.fig_to_html(highwayMpg)
html_file= open("files/highway_mpg_histogram.html","w")
html_file.write(html_str)
html_file.close()

# %%
# Prepare Data
ds = df.groupby('body-style').size().reset_index(name='count')
labels = ds.apply(lambda x: str(x[0]) + "\n (" + str(x[1]) + ")", axis=1)
sizes = ds['count'].values.tolist()
colors = [plt.cm.Spectral(i/float(len(labels))) for i in range(len(labels))]

# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
squarify.plot(sizes=sizes, label=labels, color=colors, alpha=.8)

# Decorate
plt.title('Treemap of Body Style')
plt.axis('off')
 

plt.savefig("images/body_style_treemap.png")
#Various categories of Body Style found

# %% [markdown]
# # cars performance

# %%
#Analyzing various factors that effects the performance of cars

# %%
a=df['num-of-cylinders'].unique() 
a
# Out:
# array([ 4,  6,  5,  3, 12,  2,  8], dtype=int64)

# %%
plt.figure(figsize=(10,6), dpi= 80)
sns.kdeplot(df.loc[df['num-of-cylinders'] == 3, "city-mpg"], shade=True, color="red", label="Cylinder=8", alpha=.7)
sns.kdeplot(df.loc[df['num-of-cylinders'] == 4, "city-mpg"], shade=True, color="g", label="Cylinder=4", alpha=.7)
sns.kdeplot(df.loc[df['num-of-cylinders'] == 5, "city-mpg"], shade=True, color="deeppink", label="Cylinder=5", alpha=.7)
sns.kdeplot(df.loc[df['num-of-cylinders'] == 6, "city-mpg"], shade=True, color="dodgerblue", label="Cylinder=6", alpha=.7)
sns.kdeplot(df.loc[df['num-of-cylinders'] == 8, "city-mpg"], shade=True, color="orange", label="Cylinder=8", alpha=.7)
sns.kdeplot(df.loc[df['num-of-cylinders'] == 12, "city-mpg"], shade=True, color="purple", label="Cylinder=8", alpha=.7)

# Decoration
plt.title('Density Plot of City Mileage by n_Cylinders', fontsize=22)
plt.legend()
plt.show()

plt.savefig("images/city_mpg_by_num_of_cylinders_density_plot.png")
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.lmplot('wheel-base' ,'curb-weight' , df);

plt.savefig("images/wheel_base_by_curb_weight_lmplot.png")

#wheel-base will increase with curb-weight
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#engine_size_by_curb_weight_implot

#g = sns.lmplot( 'engine-size', 'curb-weight' , df); 

#curb-weight is postively corelated with engize-size

# %%
g = sns.lmplot( 'horsepower', 'curb-weight' , df)

plt.savefig("images/horsepower_by_curb_weight_lmplot.png")
#Curb-weight increases with increase in horsepower
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#g = sns.lmplot( 'city-mpg', 'curb-weight' , df)

#Curb-weight and city-mpg are negatively corelated

# %%
g = sns.lmplot( 'horsepower', 'engine-size' , df)

plt.savefig("images/horsepower_by_engine_size_lmplot.png")

#Horsepower and engine-size are positively corelated
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#g = sns.lmplot( 'city-mpg', 'horsepower' , df)

#As the horsepower increases city mileage decreases.

# %% [markdown]
# # customer satisfaction (in terms of price)

# %%
df = df.rename(columns = {'city-mpg':'cty'})
df= df.rename(columns = {'drive-wheels':'drive'})


ds = df[['cty', 'drive']].groupby('drive').apply(lambda x: x.mean())
ds.sort_values('cty', inplace=True)
ds.reset_index(inplace=True)

#Plotting
fig, ax = plt.subplots(figsize=(10,6), dpi= 80)
ax.vlines(x=ds.index, ymin=0, ymax=ds.cty, color='green', alpha=0.7, linewidth=2)
ax.scatter(x=ds.index, y=ds.cty, s=75, color='green', alpha=0.7)

# Titles
ax.set_title('Lollipop Chart for City Mileage', fontdict={'size':20})
ax.set_ylabel('Miles Per Gallon')
ax.set_xticks(ds.index)
ax.set_xticklabels(ds.drive.str.upper(), rotation=60, fontdict={'horizontalalignment': 'right', 'size':10})
ax.set_ylim(0, 30)


for row in ds.itertuples():
    ax.text(row.Index, row.cty+.5, s=round(row.cty, 2), horizontalalignment= 'center', verticalalignment='bottom', fontsize=14)

plt.show()

df = df.rename(columns = {'cty':'city-mpg'})
df= df.rename(columns = {'drive':'drive-wheels'})


html_str = mpld3.fig_to_html(fig)
html_file= open("files/drive_wheels_by_city_mpg_lollipop.html","w")
html_file.write(html_str)
html_file.close()

#fwd provides maximum mileage
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14328\75683273.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ds = df[['cty', 'drive']].groupby('drive').apply(lambda x: x.mean())

# %%
g = sns.lmplot( 'price', 'curb-weight' , df)

plt.savefig("images/price_by_curb_weight_lmplot.png")
#curb-weight is positively co realted with price
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#g = sns.lmplot( 'price', 'city-mpg' , df)

#From earlier Analysis horsepower is positively corelated with price
#As increase in horsepower decreases the mileage, therefore city-mpg is negatively corelated with price.

# %%
plt.rcParams['figure.figsize']=(10,6)
ax = sns.boxplot(x="body-style", y="price", data=df)

plt.savefig("images/body_style_by_price_boxplot.png")
#Hardtop models are expensive
#Most of the body style  come under range of 20,00,000
#There is demand of cars which comes under the range of 15,00,000

# %%
plt.rcParams['figure.figsize']=(10,6)
ax = sns.boxplot(x="drive-wheels", y="price", data=df)

plt.savefig("images/drive_wheels_by_price_boxplot.png")
#Cars with rear-wheel drive are expensive

# %%
plt.rcParams['figure.figsize']=(10,6)
ax = sns.boxplot(x="drive-wheels", y="curb-weight", data=df)

plt.savefig("images/drive_wheels_by_curb_weight_boxplot.png")

# %%
sns.catplot(data=df, x="body-style", y="price", hue="num-of-cylinders" ,kind="point")

plt.savefig("images/body_style_by_price_point.png")

#city-mpg more with less number of cylinders.
